# %% [markdown]
# # Add library to my project

# %%
import numpy as np
from scipy.fftpack import fft
import matplotlib.pyplot as plt

# %% [markdown]
# # make my function

# %%
x = lambda t: 6 * np.sin(4 * t * np.pi) + 7 * np.sin(9 * t * np.pi)

# %% [markdown]
# # make my signal

# %%
signal = np.linspace(-np.pi , np.pi, 1000)

# %% [markdown]
# # Apply my function

# %%
new_signal = list(map(x, signal))

# %% [markdown]
# # Show singnal with plot

# %%
plt.plot(signal, new_signal)
plt.show()

# %% [markdown]
# # make fft function

# %%
def MyFt(Signal, Fs):
    MFT = fft(Signal);
    Freq = np.linspace(-Fs/2,Fs/2,len(Signal))
    MFT = MFT[Freq >= 0]
    Freq = Freq[Freq >= 0]
    MFT = MFT[::-1]
    MFT[2:] = 2*MFT[2:]
    return Freq, abs(MFT)/len(Signal);

# %% [markdown]
# # Apply FFT function

# %%
freq, sig = MyFt(new_signal, 1000)

# %% [markdown]
# # Show the output

# %%
plt.plot(freq, sig)
plt.show()
